# %% [markdown]
# # Week 3 handin

# %% [markdown]
# ## 01 Assignment
# Here is the text for the assignment linked to

# %% [markdown]
# ## 02 Status
# De fleste opgaver til solution 1 er lavet. Ekstra opgaver mangler. Filen ligger i Week_3_file.py

# %% [markdown]
# ## 03 Solution part 1

# %%
# 1.1 generate random students and send them to csv file

from Week_3_file import Student, DataSheet, Course, createStudents, readStudents
createStudents(5)

# %%
# 1.2 read data from csv file and send it to a list

readStudents()
# Out:
# [['Stud_name: Lis',
#   'course_name: Python',
#   'teacher: Thomas',
#   'ects: 30',
#   'classroom: Room47',
#   'grade: 7'],
#  ['Stud_name: Lis',
#   'course_name: Discrete Math',
#   'teacher: Eko',
#   'ects: 15',
#   'classroom: Room39',
#   'grade: 4'],
#  ['Stud_name: Lis',
#   'course_name: Discrete Math',
#   'teacher: Eko',
#   'ects: 15',
#   'classroom: Room39',
#   'grade: 4'],
#  ['Stud_name: Lis',
#   'course_name: Algos',
#   'teacher: Al',
#   'ects: 20',
#   'classroom: Room12',
#   'grade: 10'],
#  ['Stud_name: Lis',
#   'course_name: Discrete Math',
#   'teacher: Eko',
#   'ects: 15',
#   'classroom: Room39',
#   'grade: 4'],
#  ['Stud_name: Lis',
#   'course_name: Java Advanced',
#   'teacher: Al',
#   'ects: 15',
#   'classroom: Room15',
#   'grade: 2'],
#  ['Stud_name: Lis',
#   'course_name: Python',
#   'teacher: Thomas',
#   'ects: 30',
#   'classroom: Room47',
#   'grade: 7'],
#  ['Stud_name: Lis',
#   'course_name: Python Advanced',
# ...

# %%
# 1.3

# %% [markdown]
# ## 04 Solution part 2

# %%
# 2.1
