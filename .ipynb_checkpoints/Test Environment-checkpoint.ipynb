# %%
from Week_3_file import Student, DataSheet, Course, createStudents, readStudents, readStudentsImprov, studentBar



createStudents(5)

#readStudents()


li = readStudentsImprov()

#for i in li:
#    print(i.name)
#    print("--------------------------------------------------")
#    for e in i.datasheet.courses:
#        print(e.name)
#    print("-----------------end")

studentBar()
# Out:
# 10
#
# 2
#
# 10
#
# 2
#
# 2
#
# 10
#
# 12
#
# 4
#
# 10
#
# 2
#
# 10
#
# 2
#
# 2
#
# 10
#
# 12
#
# 4
#
# 10
#
# 2
#
# 10
#
# 2
#
# 2
#
# 10
#
# 12
#
# 4
#
# 10
#
# 2
#
# 10
#
# 2
#
# 2
#
# 10
#
# 12
#
# 4
#
# 10
#
# 2
#
# 10
#
# 2
#
# 2
#
# 10
#
# 12
#
# 4
#
# 10
#
# 2
#
# 10
#
# 2
#
# 2
#
# 10
#
# 12
#
# 4
#
# 10
#
# 2
#
# 10
#
# 2
#
# 2
#
# 10
#
# 12
#
# 4
#
# 10
#
# 2
#
# 10
#
# 2
#
# 2
#
# 10
#
# 12
#
# 4
#
# 10
#
# 2
#
# 10
#
# 2
#
# 2
#
# 10
#
# 12
#
# 4
#
# 10
#
# 2
#
# 10
#
# 2
#
# 2
#
# 10
#
# 12
#
# 4
#
# Sally
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-d15e67e5e467> in <module>
#      17 #    print("-----------------end")
#      18
# ---> 19 studentBar()
#
# ~/python_handin_template/Week_3_file.py in studentBar()
#      39     for student in students:
#      40         print(student.name)
# ---> 41         print(student.datasheet.courses[0].grade)
#      42         #plt.bar([student.name], [student.get_avg_grade()],width=0.5, align='center')
#      43         #plt.xticks(rotation=45, horizontalalignment='right',fontweight='light')
#
# AttributeError: 'Course' object has no attribute 'grade'
