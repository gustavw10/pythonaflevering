# %%
from Week_3_file import Student, DataSheet, Course, createStudents, readStudents, readStudentsImprov, studentBar



#createStudents(5)

#readStudents()


li = readStudentsImprov()

#for i in li:
#    print(i.name)
#    print("--------------------------------------------------")
#    for e in i.datasheet.courses:
#        print(e.name)
#    print("-----------------end")

studentBar()
# Out:
# 4
# 4
# 4
# 7
# 4
# 4
# 4
# 4
# 4
# 12
# 4
# 4
# 12
# 4
# 4
# 4
# 7
# 4
# 4
# 4
# 4
# 4
# 12
# 4
# 4
# 12
# 4
# 4
# 4
# 7
# 4
# 4
# 4
# 4
# 4
# 12
# 4
# 4
# 12
# 4
# 4
# 4
# 7
# 4
# 4
# 4
# 4
# 4
# 12
# 4
# 4
# 12
# 4
# 4
# 4
# 7
# 4
# 4
# 4
# 4
# 4
# 12
# 4
# 4
# 12
# 4
# 4
# 4
# 7
# 4
# 4
# 4
# 4
# 4
# 12
# 4
# 4
# 12
# 4
# 4
# 4
# 7
# 4
# 4
# 4
# 4
# 4
# 12
# 4
# 4
# 12
# 4
# 4
# 4
# 7
# 4
# 4
# 4
# 4
# 4
# 12
# 4
# 4
# 12
# 4
# 4
# 4
# 7
# 4
# 4
# 4
# 4
# 4
# 12
# 4
# 4
# 12
# 4
# 4
# 4
# 7
# 4
# 4
# 4
# 4
# 4
# 12
# 4
# 4
# 12
# Bek
# Room39
#
# Sva
# Room39
#
# Ta
# Room39
#
# Tom
# Room39
#
# Bea
# Room39
